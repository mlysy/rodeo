# %%
from fitz_solve import fitzsolve_example

fitzsolve_example()

# %%
from chkrebtii_graph import graph
graph()

# %% [markdown]
# For Figure 2, 3 in the paper, please run the cell below. May take ~5 minutes.

# %%
from fitz import fitz_example

fitz_example(False)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 10
# 20
# 50
# 100

# %% [markdown]
# For Figure 4 in the paper, please run the cell below. May take a ~5 minutes.

# %%
from hes1 import hes1_example

hes1_example(False)
# Out:
# 128
# 160
# 192
# 320

# %% [markdown]
# For Figure 5 in the paper, please run the cell below. May take ~5 minutes.

# %%
from seirah import seirah_example

seirah_example(False)
# Out:
# 600
# 1200
# 3000
# 6000
