# %% [markdown]
# For Figure 4 in the paper, please run the cell below. May take ~5 minutes.

# %%
from fitz import fitz_example

fitz_example(False)

# %% [markdown]
# For Figure 3 in the paper, please run the cell below. May take a ~5 minutes.

# %%
from hes1 import hes1_example
hes1_example(False)

# %% [markdown]
# For Figure 4 in the paper, please run the cell below. May take ~5 minutes.

# %%
from seirah import seirah_example

seirah_example(False)
